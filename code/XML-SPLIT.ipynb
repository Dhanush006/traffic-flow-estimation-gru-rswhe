# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/MyDrive/IT-CV/Datasets/UA-DETRAC/Train/ANNOTS/MVI_20061/'
# Out:
# /content/gdrive/MyDrive/IT-CV/Datasets/UA-DETRAC/Train/ANNOTS/MVI_20061

# %%
import xml.etree.ElementTree as ET
context = ET.iterparse('/content/gdrive/MyDrive/IT-CV/Datasets/UA-DETRAC/Train/ANNOTS/MVI_20061/MVI_20061.xml', events=('end', ))
index = 0
for event, elem in context:
    if elem.tag == 'frame':
        index += 1
        filename = format(str(index) + ".xml")
        with open(filename, 'wb') as f:
            # f.write("<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n")
            f.write(ET.tostring(elem))
